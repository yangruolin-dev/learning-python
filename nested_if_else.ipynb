# %%
num = 10
if int(input("请输入第一次猜想的数字：")) == num:
    print("恭喜你，第一次就猜对了")
elif int(input("猜错了，再猜一次：")) == num:
    print("恭喜你，猜对了")
elif int(input("不对，再猜最后一次：")) == num:
    print("恭喜你，猜对了")
else:
    print("Sorry,猜错了")
# Out:
# 请输入第一次猜想的数字： 1
# 猜错了，再猜一次： 2
# 不对，再猜最后一次： 3
# Sorry,猜错了
