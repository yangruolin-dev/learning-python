# %%
age = int(input())
if age >= 18:
    print(f"请输入你的年龄{age},您已成年,游玩需要补票10元。")
# Out:
#  30
# 请输入你的年龄30,您已成年,游玩需要补票10元。

# %%
age = int(input("请输入你的年龄:"))
if age >= 18:
    print("您已成年,游玩需要补票10元。")
print("祝您游玩愉快")
# Out:
# 请输入你的年龄: 30
# 您已成年,游玩需要补票10元。
# 祝您游玩愉快
