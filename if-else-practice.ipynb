# %%
height = int(input("请输入你的身高(cm)："))
if height >= 120:
    print("您的身高超出120cm，游玩需要购票10元。")
else :
    print("您的身高未超出120cm，可以免费游玩")
print("祝您游玩愉快。")
# Out:
# 请输入你的身高(cm)： 111
# 您的身高未超出120cm，可以免费游玩
# 祝您游玩愉快。
