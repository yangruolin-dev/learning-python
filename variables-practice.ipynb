# %%
money=50
print("当前钱包余额:",50,"元")
a=10
print("购买了冰淇淋，花费:",a,"元")
b=5
print("购买了可乐，花费:",b,"元")
money=money-a-b
print("最终，钱包剩余:",money,"元")
# Out:
# 当前钱包余额: 50 元
# 购买了冰淇淋，花费: 10 元
# 购买了可乐，花费: 5 元
# 最终，钱包剩余: 35 元
