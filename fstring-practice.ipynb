# %%
name = "传智播客"
stock_code = "003032"
stock_price = 19.99
stock_price_daliy_grownth_factor = 1.2
grownth_days = 7
result = stock_price*(stock_price_daliy_grownth_factor**grownth_days)
print(f"公司:{name}，股票代码:{stock_code}，当前股价:{stock_price}\n")
print("每日增长系数是:%.1f,经过%d天的增长后，股价达到了%.2f",stock_price_daliy_grownth_factor,grownth_days,result)
# Out:
# 公司:传智播客，股票代码:003032，当前股价:19.99
#
# 每日增长系数是:%.1f,经过%d天的增长后，股价达到了%.2f 1.2 7 71.62778419199998
